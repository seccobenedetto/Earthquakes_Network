# %% [markdown]
# # Creation of Abe-Suzuki Earthquake Network

# %% [markdown]
# ## Creating two types of networks with different cell size $5\times5\times5 km^3$ and $10\times10\times10 km^3$

# %%
import pandas as pd
import numpy as np
import networkx as nx
from pyproj import Transformer
import time

def discretize_space_3d(df, cell_size_km):
    """
    Converts geographic coordinates to a 3D Cartesian grid and assigns each 
    earthquake to a specific cubic cell.
    """
    print(f"Projecting coordinates and creating {cell_size_km}x{cell_size_km}x{cell_size_km} km grid...")
    
    # We use NAD83 / Conus Albers (EPSG:5070), which is the standard for the lower 48 states.
    transformer = Transformer.from_crs("epsg:4326", "epsg:5070", always_xy=True)
    x_meters, y_meters = transformer.transform(df['longitude'].values, df['latitude'].values)
    
    # meters to kilometers
    df['x_km'] = x_meters / 1000.0
    df['y_km'] = y_meters / 1000.0
    df['z_km'] = df['depth_km'].values # Z is already in km
    
    # shift coordinates so the minimum value is 0
    x_shifted = df['x_km'] - df['x_km'].min()
    y_shifted = df['y_km'] - df['y_km'].min()
    z_shifted = df['z_km'] - df['z_km'].min()
    
    # Calculate cell indices (i, j, k)
    df['cell_x'] = np.floor(x_shifted / cell_size_km).astype(int)
    df['cell_y'] = np.floor(y_shifted / cell_size_km).astype(int)
    df['cell_z'] = np.floor(z_shifted / cell_size_km).astype(int)
    
    # Create a unique string ID for each cell (e.g., "12_45_2")
    df['cell_id'] = df['cell_x'].astype(str) + "_" + \
                    df['cell_y'].astype(str) + "_" + \
                    df['cell_z'].astype(str)
    
    return df

def build_abe_suzuki_network(df, cell_size_km):
    """
    Builds the Abe-Suzuki directed network where nodes are 3D spatial cells
    and edges are consecutive seismic events.
    """
    start_time = time.time()
    
    # Assign cells to eq
    df_grid = discretize_space_3d(df.copy(), cell_size_km)
    
    # Extract the sequence of cell IDs chronologically
    cell_sequence = df_grid['cell_id'].tolist()
    
    # Initialize Directed Graph
    G = nx.DiGraph()
    
    print("Building network edges from consecutive events...")
    
    # Iterate through the sequence
    for i in range(len(cell_sequence) - 1):
        source_cell = cell_sequence[i]
        target_cell = cell_sequence[i + 1]
        
        # If the edge already exists, just increase its weight (transition frequency)
        if G.has_edge(source_cell, target_cell):
            G[source_cell][target_cell]['weight'] += 1
        else:
            # Create a new edge with weight 1
            G.add_edge(source_cell, target_cell, weight=1)
            
    # Add basic attributes to nodes
    # geographic center of each cell just in case we want to plot them
    cell_centers = df_grid.groupby('cell_id')[['longitude', 'latitude']].mean()
    for node in G.nodes():
        if node in cell_centers.index:
            G.nodes[node]['lat'] = cell_centers.loc[node, 'latitude']
            G.nodes[node]['lon'] = cell_centers.loc[node, 'longitude']

    execution_time = time.time() - start_time
    print(f"\n--- Abe-Suzuki Network ({cell_size_km}km resolution) ---")
    print(f"Nodes (Active Cells): {G.number_of_nodes()}")
    print(f"Edges (Transitions): {G.number_of_edges()}")
    print(f"Self-Loops (Successive events in same cell): {nx.number_of_selfloops(G)}")
    print(f"Execution time: {execution_time:.2f} seconds")
    
    return G

print("Loading dataset...")
df = pd.read_csv("data/USGS/us_earthquakes_1985_2025.csv")
df['time'] = pd.to_datetime(df['time'], utc=True)
cut_year = 1985
df_net = df[df['time'].dt.year >= cut_year].sort_values('time').reset_index(drop=True)

# Build the 5x5x5 km network
G_5km = build_abe_suzuki_network(df_net, cell_size_km=5)

print("\n" + "="*40 + "\n")

# Build the 10x10x10 km network
G_10km = build_abe_suzuki_network(df_net, cell_size_km=10)
# Out:
# Loading dataset...
# Projecting coordinates and creating 5x5x5 km grid...
# Building network edges from consecutive events...
#
# --- Abe-Suzuki Network (5km resolution) ---
# Nodes (Active Cells): 50273
# Edges (Transitions): 285290
# Self-Loops (Successive events in same cell): 4033
# Execution time: 3.76 seconds
#
# ========================================
#
# Projecting coordinates and creating 10x10x10 km grid...
# Building network edges from consecutive events...
#
# --- Abe-Suzuki Network (10km resolution) ---
# Nodes (Active Cells): 23198
# Edges (Transitions): 238151
# Self-Loops (Successive events in same cell): 2901
# Execution time: 2.02 seconds

# %% [markdown]
# ## Analysis degree distribution

# %% [markdown]
# #### degree distribution of each node

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import linregress
import seaborn as sns

sns.set_theme(style="whitegrid")

def analyze_degree_distribution(G, title):
    """
    Extracts the degree of each node, calculates the probability distribution P(k),
    and fits a power-law to verify the scale-free property.
    """
    # ignore isolated nodes (degree 0)
    degrees = [d for n, d in G.degree() if d > 0]
    
    # frequencies and probabilities
    degree_counts = pd.Series(degrees).value_counts().sort_index()
    k = degree_counts.index.values
    P_k = degree_counts.values / len(degrees)
    
    # Log-Log Linear Regression
    valid_idx = k >= 2
    log_k = np.log10(k[valid_idx])
    log_P = np.log10(P_k[valid_idx])
    
    slope, intercept, r_value, _, _ = linregress(log_k, log_P)
    
    # In a log-log plot of a power law, the slope is -gamma
    gamma = -slope
    plt.figure(figsize=(9, 6))
    plt.scatter(k, P_k, color='royalblue', alpha=0.7, edgecolors='k', label='Observed Data')
    fit_line = 10**(intercept) * (k[valid_idx]**(-gamma))
    plt.plot(k[valid_idx], fit_line, color='crimson', linewidth=2, linestyle='--',
             label=fr'Power-law fit ($\gamma \approx {gamma:.2f}$)')
    plt.xscale('log')
    plt.yscale('log')
    plt.title(f'Degree Distribution: {title}', fontsize=15)
    plt.xlabel('Degree $k$', fontsize=13)
    plt.ylabel('Probability $P(k)$', fontsize=13)
    plt.legend(fontsize=12)
    plt.grid(True, which="both", ls="--", alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    print(f"[{title}] Power-law exponent gamma: {gamma:.3f} (R-squared: {r_value**2:.3f})")

print("Analyzing 5km Resolution Network...")
analyze_degree_distribution(G_5km, "Abe-Suzuki Network (5x5x5 km)")

print("\nAnalyzing 10km Resolution Network...")
analyze_degree_distribution(G_10km, "Abe-Suzuki Network (10x10x10 km)")
# Out:
# Analyzing 5km Resolution Network...
# [Abe-Suzuki Network (5x5x5 km)] Power-law exponent gamma: 1.394 (R-squared: 0.814)
#
# Analyzing 10km Resolution Network...
# [Abe-Suzuki Network (10x10x10 km)] Power-law exponent gamma: 1.259 (R-squared: 0.823)

# %% [markdown]
# #### degree distribution with LOG-BINNING

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import seaborn as sns

sns.set_theme(style="whitegrid")

def analyze_degree_distribution_log_binning(G, title, k_min_fit=10):
    """
    Analyzes the degree distribution using Logarithmic Binning, 
    which is the standard scientific approach for scale-free networks 
    to handle the heavy-tail noise.
    """
    degrees = [d for n, d in G.degree() if d > 0]
    
    if not degrees:
        print("Graph has no edges.")
        return
        
    k_min = min(degrees)
    k_max = max(degrees)
    
    # Logarithmic Bins
    num_bins = 25
    bins = np.logspace(np.log10(k_min), np.log10(k_max), num_bins)
    
    # Histogram
    counts, bin_edges = np.histogram(degrees, bins=bins)
    
    # bin centers and bin widths
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    bin_widths = np.diff(bin_edges)
    
    # Normalize to Probability Density P(k)
    # We must divide by the width of the bin
    P_k = counts / (len(degrees) * bin_widths)
    
    # Filter empty bins
    valid_mask = P_k > 0
    k_valid = bin_centers[valid_mask]
    P_k_valid = P_k[valid_mask]
    
    # fit the Power-Law only on the valid structural tail (k >= k_min_fit)
    fit_mask = k_valid >= k_min_fit
    
    if sum(fit_mask) > 2:
        log_k = np.log10(k_valid[fit_mask])
        log_P = np.log10(P_k_valid[fit_mask])
        slope, intercept, r_value, _, _ = linregress(log_k, log_P)
        gamma = -slope
        fit_line = 10**(intercept) * (k_valid[fit_mask]**(-gamma))
    else:
        gamma, r_value, fit_line = 0, 0, []

    plt.figure(figsize=(9, 6))
    plt.scatter(k_valid, P_k_valid, color='darkviolet', alpha=0.8, 
                edgecolors='k', s=60, label='Log-Binned Data')
    if sum(fit_mask) > 2:
        plt.plot(k_valid[fit_mask], fit_line, color='crimson', linewidth=2.5, 
                 linestyle='--', label=fr'Power-law fit ($k \geq {k_min_fit}$): $\gamma \approx {gamma:.2f}$')
    
    plt.xscale('log')
    plt.yscale('log')
    plt.title(f'Degree Distribution (Log-Binning): {title}', fontsize=15)
    plt.xlabel('Degree $k$', fontsize=13)
    plt.ylabel('Probability Density $P(k)$', fontsize=13)
    plt.legend(fontsize=12)
    plt.grid(True, which="both", ls="--", alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    print(f"[{title}] Power-law exponent gamma: {gamma:.3f} (R-squared: {r_value**2:.3f})")

analyze_degree_distribution_log_binning(G_5km, "Abe-Suzuki Network (5x5x5 km)", k_min_fit=10)
analyze_degree_distribution_log_binning(G_10km, "Abe-Suzuki Network (10x10x10 km)", k_min_fit=10)
# Out:
# Analyzing 5km Resolution Network with Log-Binning...
# [Abe-Suzuki Network (5x5x5 km)] Power-law exponent gamma: 2.433 (R-squared: 0.985)
#
# Analyzing 10km Resolution Network with Log-Binning...
# [Abe-Suzuki Network (10x10x10 km)] Power-law exponent gamma: 2.299 (R-squared: 0.976)

# %% [markdown]
# ## Mapping the top 2% Hubs

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
import networkx as nx

pio.renderers.default = 'iframe' 

# Extract degrees and coordinates from the network
print("Extracting node metrics...")
node_data = []
for node in G_10km.nodes():
    # nodes that have coordinates
    if 'lat' in G_10km.nodes[node] and 'lon' in G_10km.nodes[node]:
        node_data.append({
            'cell_id': node,
            'degree': G_10km.degree(node),
            'lat': G_10km.nodes[node]['lat'],
            'lon': G_10km.nodes[node]['lon']
        })

df_nodes = pd.DataFrame(node_data)

# Filter out isolated cells
df_nodes = df_nodes[df_nodes['degree'] > 0]

# Identify Hubs
threshold = df_nodes['degree'].quantile(0.98)
df_hubs = df_nodes[df_nodes['degree'] >= threshold].copy()

print(f"Total active cells: {len(df_nodes)}")
print(f"Mapping the top {len(df_hubs)} Hubs (Degree >= {threshold:.0f})...")

# Plot Hubs 
fig = px.scatter_mapbox(
    df_hubs, 
    lat="lat", 
    lon="lon", 
    color="degree",
    size="degree",
    color_continuous_scale="inferno",
    zoom=3.5,
    center={"lat": 37.3, "lon": -95.0},
    mapbox_style="carto-positron",
    hover_name="cell_id",
    hover_data={"lat": ":.3f", "lon": ":.3f", "degree": True},
    title="Abe-Suzuki Network Hubs: Top 2% Most Active Seismic Cells (10x10x10 km)"
)

fig.update_layout(margin={"r": 0, "t": 40, "l": 0, "b": 0})
fig.show()
# Out:
# Extracting node metrics...
# Total active cells: 29891
# Mapping the top 598 Hubs (Degree >= 149)...
# /tmp/ipykernel_1144174/1633632459.py:34: DeprecationWarning: *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig = px.scatter_mapbox(
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_13.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Generating upgraded 3D Network Hub Map with US surface map

# %%
import plotly.graph_objects as go
import plotly.express as px
import geopandas as gpd
import pandas as pd

# download from https://www.naturalearthdata.com/
print("Download USA's 48 states geometry to draw the surface map")

# Fetch USA Boundaries
url = "https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip"
world = gpd.read_file(url)
full_usa_geom = world[world['ADMIN'] == "United States of America"].geometry.iloc[0]
us_geom = max(full_usa_geom.geoms, key=lambda p: p.area)

geometries = [us_geom]
df_hubs['depth_km'] = df_hubs['cell_id'].apply(lambda x: float(x.split('_')[2]) * 10)

lons_map, lats_map, zs_map = [], [], []
for polygon in geometries:
    x, y = polygon.exterior.coords.xy
    lons_map.extend(x)
    lats_map.extend(y)
    zs_map.extend([0] * len(x)) # map at surface level
    
    lons_map.append(None)
    lats_map.append(None)
    zs_map.append(None)

print("3D Network Hub Map...")

# 3D Scatter the Hubs
fig_3d = px.scatter_3d(
    df_hubs, 
    x='lon', y='lat', z='depth_km',
    color='degree', size='degree',
    color_continuous_scale='inferno',
    hover_name='cell_id',
    hover_data={'lat': ':.2f', 'lon': ':.2f', 'depth_km': True, 'degree': True}
)

# map outline
fig_3d.add_trace(go.Scatter3d(
    x=lons_map, y=lats_map, z=zs_map,
    mode='lines',
    line=dict(color='blue', width=3),
    name='USA Surface (0 km)',
    hoverinfo='skip'
))

# Configure the axes
fig_3d.update_layout(
    template="plotly_white",
    scene=dict(
        zaxis=dict(autorange="reversed", title="Depth (km)"),
        xaxis=dict(title="Longitude"),
        yaxis=dict(title="Latitude"),
        aspectratio=dict(x=1.8, y=1, z=0.5) 
    ),
    margin=dict(l=0, r=0, b=0, t=40),
    title="3D View of Seismic Hubs with Surface Coastline"
)

# remove points border
fig_3d.update_traces(marker=dict(line=dict(width=0)))
fig_3d.show()
# Out:
# Download USA's 48 states geometry to draw the surface map
# 3D Network Hub Map...
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_19.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Macroscopic Network Analysis

# %% [markdown]
# ## Calculating some metrics
# - Giant Component Analysis
# - Clustering coefficients
# - Diameter and Path average length
# - Adjacency Matrix

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.sparse as sp

# Assuming G_10km is loaded from the previous steps
G = G_10km

print("  MACROSCOPIC SEISMIC NETWORK ANALYSIS   ")
print("--- Giant Component Analysis ---")
# In directed graphs, we use Weakly Connected Components
# to find the overall physical structure.
wcc = list(nx.weakly_connected_components(G))
largest_wcc_nodes = max(wcc, key=len)
G_giant = G.subgraph(largest_wcc_nodes).copy()

total_nodes = G.number_of_nodes()
giant_nodes = G_giant.number_of_nodes()
percentage = (giant_nodes / total_nodes) * 100

print(f"Total isolated components: {len(wcc)}")
print(f"Giant Component Size: {giant_nodes} nodes ({percentage:.2f}% of the whole network)")

# Clustering Coefficient (Triangles)
print("--- Clustering Coefficient ---")
# To analyze physical triangles (A-B-C-A), we convert to undirected
# to avoid directional strictness
G_undirected = G_giant.to_undirected()

# Remove self-loops for clustering calculation
G_undirected.remove_edges_from(nx.selfloop_edges(G_undirected))

start_time = time.time()
avg_clustering = nx.average_clustering(G_undirected)
print(f"Average Clustering Coefficient (C): {avg_clustering:.4f}")

# Calculate the clustering of a random graph with the same nodes and edges for comparison
p_random = (2 * G_undirected.number_of_edges()) / (giant_nodes * (giant_nodes - 1))
print(f"Expected C for a Random Graph:    {p_random:.4f}")

# Path Length and Diameter
print("--- Diameter & Average Path Length ---")
print("Calculating shortest paths...")

start_time = time.time()
# We compute this on the Undirected Giant Component. 
# (In a DiGraph, if there is no path back in time, the distance is infinite).
avg_path_length = nx.average_shortest_path_length(G_undirected)
diameter = nx.diameter(G_undirected)
calc_time = time.time() - start_time

print(f"Average Path Length (L): {avg_path_length:.2f} steps")
print(f"Network Diameter:        {diameter} steps")
print(f"Calculation time:        {calc_time:.1f} seconds")

# adjacency Matrix & Sparsity
print("--- 4. Adjacency Matrix ---")
# Extract as a scipy sparse matrix for memory efficiency
adj_matrix = nx.to_scipy_sparse_array(G)
sparsity = 1.0 - (adj_matrix.nnz / (total_nodes ** 2))

print(f"Matrix Shape: {adj_matrix.shape}")
print(f"Non-Zero elements (Edges): {adj_matrix.nnz}")
print(f"Matrix Sparsity: {sparsity * 100:.4f}%")

# Plotting the Adjacency Matrix
plt.figure(figsize=(8, 8))
plt.spy(adj_matrix, markersize=0.05, color='darkblue')
plt.title("Adjacency Matrix (Sparsity Pattern)\nEach dot is a temporal connection between cells", fontsize=14)
plt.xlabel("Target Cell Index", fontsize=12)
plt.ylabel("Source Cell Index", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# =========================================
#   MACROSCOPIC SEISMIC NETWORK ANALYSIS
# =========================================
#
# --- 1. Giant Component Analysis ---
# Total isolated components: 1
# Giant Component Size: 29891 nodes (100.00% of the whole network)
# Physical Meaning: 100.00% of active Italian seismic cells are structurally linked together.
#
# --- 2. Clustering Coefficient ---
# Average Clustering Coefficient (C): 0.2188
# Expected C for a Random Graph:    0.0005
# Physical Meaning: A C value much higher than the random expectation proves intense local aftershock clustering.
#
# --- 3. Diameter & Average Path Length ---
# Calculating shortest paths... (takes a bit...)
# Average Path Length (L): 3.18 steps
# Network Diameter:        7 steps
# Calculation time:        5297.9 seconds
# Physical Meaning: On average, any seismic cell is only 3.18 'jumps' away from any other cell in Italy.
#
# --- 4. Adjacency Matrix ---
# Matrix Shape: (29891, 29891)
# Non-Zero elements (Edges): 255319
# Matrix Sparsity: 99.9714%

# %% [markdown]
# ## CALCULATING GLOBAL CENTRALITY METRICS
# - Degree Centrality
# - PageRank
# - Closeness Centrality
# - Betweenness Centrality (K=1000)

# %%
import pandas as pd
import networkx as nx
import time

print("  CALCULATING GLOBAL CENTRALITY METRICS  ")

start_time = time.time()

# Degree Centrality (Normalized degree)
print("Computing Degree Centrality...")
deg_cent = nx.degree_centrality(G_10km)

# PageRank Centrality
print("Computing PageRank Centrality...")
pagerank_cent = nx.pagerank(G_10km, weight='weight')

# closeness Centrality
print("Computing Closeness Centrality...")
close_cent = nx.closeness_centrality(G_10km)

# Betweenness Centrality
print("Computing Betweenness Centrality...")
bet_cent = nx.betweenness_centrality(G_10km, k=1000, seed=42)

calc_time = time.time() - start_time
print(f"\nAll metrics calculated in {calc_time:.1f} seconds!")

# Build DB
metrics_data = []
for node in G_10km.nodes():
    if 'lat' in G_10km.nodes[node] and 'lon' in G_10km.nodes[node]:
        metrics_data.append({
            'cell_id': node,
            'lat': G_10km.nodes[node]['lat'],
            'lon': G_10km.nodes[node]['lon'],
            'depth_km': float(node.split('_')[2]) * 10,  # Recover depth from ID
            'Degree': deg_cent[node],
            'Betweenness': bet_cent[node],
            'Closeness': close_cent[node],
            'PageRank': pagerank_cent[node]
        })

df_centrality = pd.DataFrame(metrics_data)

# Top 5 Cells for Each Metric
def display_top_5(df, metric, title):
    print(f"\n--- Top 5 Cells: {title} ---")
    top_5 = df.sort_values(metric, ascending=False).head(5)
    display(top_5[['cell_id', 'lat', 'lon', 'depth_km', metric]].style.format({
        'lat': "{:.3f}", 'lon': "{:.3f}", 'depth_km': "{:.1f}", metric: "{:.6f}"
    }))

display_top_5(df_centrality, 'Degree', 'Most Active Swarms (Degree)')
display_top_5(df_centrality, 'Betweenness', 'Structural Bridges (Betweenness)')
display_top_5(df_centrality, 'Closeness', 'Topological Centers (Closeness)')
display_top_5(df_centrality, 'PageRank', 'Stress Sinks (PageRank)')
# Out:
# =========================================
#   CALCULATING GLOBAL CENTRALITY METRICS
# =========================================
#
# 1/4 Computing Degree Centrality...
# 2/4 Computing PageRank Centrality...
# 3/4 Computing Closeness Centrality (This might take a bit)...
# 4/4 Computing Betweenness Centrality (Sampled k=1000)...
#
# All metrics calculated in 1524.9 seconds!
#
# --- Top 5 Cells: Most Active Swarms (Degree) ---
# <style type="text/css">
# </style>
# <table id="T_e14bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e14bb_level0_col0" class="col_heading level0 col0" >cell_id</th>
#       <th id="T_e14bb_level0_col1" class="col_heading level0 col1" >lat</th>
#       <th id="T_e14bb_level0_col2" class="col_heading level0 col2" >lon</th>
#       <th id="T_e14bb_level0_col3" class="col_heading level0 col3" >depth_km</th>
#       <th id="T_e14bb_level0_col4" class="col_heading level0 col4" >Degree</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e14bb_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_e14bb_row0_col0" class="data row0 col0" >487_743_0</td>
#       <td id="T_e14bb_row0_col1" class="data row0 col1" >38.824</td>
#       <td id="T_e14bb_row0_col2" class="data row0 col2" >-122.819</td>
#       <td id="T_e14bb_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_e14bb_row0_col4" class="data row0 col4" >0.252760</td>
#     </tr>
#     <tr>
#       <th id="T_e14bb_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_e14bb_row1_col0" class="data row1 col0" >486_743_0</td>
#       <td id="T_e14bb_row1_col1" class="data row1 col1" >38.798</td>
#       <td id="T_e14bb_row1_col2" class="data row1 col2" >-122.773</td>
#       <td id="T_e14bb_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_e14bb_row1_col4" class="data row1 col4" >0.218501</td>
#     </tr>
#     <tr>
#       <th id="T_e14bb_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_e14bb_row2_col0" class="data row2 col0" >541_661_0</td>
#       <td id="T_e14bb_row2_col1" class="data row2 col1" >46.197</td>
#       <td id="T_e14bb_row2_col2" class="data row2 col2" >-122.190</td>
#       <td id="T_e14bb_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_e14bb_row2_col4" class="data row2 col4" >0.115423</td>
#     </tr>
#     <tr>
#       <th id="T_e14bb_level0_row3" class="row_heading level0 row3" >54</th>
#       <td id="T_e14bb_row3_col0" class="data row3 col0" >485_743_0</td>
#       <td id="T_e14bb_row3_col1" class="data row3 col1" >38.759</td>
#       <td id="T_e14bb_row3_col2" class="data row3 col2" >-122.716</td>
#       <td id="T_e14bb_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_e14bb_row3_col4" class="data row3 col4" >0.072600</td>
#     </tr>
#     <tr>
#       <th id="T_e14bb_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_e14bb_row4_col0" class="data row4 col0" >486_742_0</td>
#       <td id="T_e14bb_row4_col1" class="data row4 col1" >38.826</td>
#       <td id="T_e14bb_row4_col2" class="data row4 col2" >-122.762</td>
#       <td id="T_e14bb_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_e14bb_row4_col4" class="data row4 col4" >0.058648</td>
#     </tr>
#   </tbody>
# </table>
# --- Top 5 Cells: Structural Bridges (Betweenness) ---
# <style type="text/css">
# </style>
# <table id="T_03d9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03d9d_level0_col0" class="col_heading level0 col0" >cell_id</th>
#       <th id="T_03d9d_level0_col1" class="col_heading level0 col1" >lat</th>
#       <th id="T_03d9d_level0_col2" class="col_heading level0 col2" >lon</th>
#       <th id="T_03d9d_level0_col3" class="col_heading level0 col3" >depth_km</th>
#       <th id="T_03d9d_level0_col4" class="col_heading level0 col4" >Betweenness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03d9d_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_03d9d_row0_col0" class="data row0 col0" >487_743_0</td>
#       <td id="T_03d9d_row0_col1" class="data row0 col1" >38.824</td>
#       <td id="T_03d9d_row0_col2" class="data row0 col2" >-122.819</td>
#       <td id="T_03d9d_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_03d9d_row0_col4" class="data row0 col4" >0.208475</td>
#     </tr>
#     <tr>
#       <th id="T_03d9d_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_03d9d_row1_col0" class="data row1 col0" >486_743_0</td>
#       <td id="T_03d9d_row1_col1" class="data row1 col1" >38.798</td>
#       <td id="T_03d9d_row1_col2" class="data row1 col2" >-122.773</td>
#       <td id="T_03d9d_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_03d9d_row1_col4" class="data row1 col4" >0.169674</td>
#     </tr>
#     <tr>
#       <th id="T_03d9d_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_03d9d_row2_col0" class="data row2 col0" >541_661_0</td>
#       <td id="T_03d9d_row2_col1" class="data row2 col1" >46.197</td>
#       <td id="T_03d9d_row2_col2" class="data row2 col2" >-122.190</td>
#       <td id="T_03d9d_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_03d9d_row2_col4" class="data row2 col4" >0.053934</td>
#     </tr>
#     <tr>
#       <th id="T_03d9d_level0_row3" class="row_heading level0 row3" >54</th>
#       <td id="T_03d9d_row3_col0" class="data row3 col0" >485_743_0</td>
#       <td id="T_03d9d_row3_col1" class="data row3 col1" >38.759</td>
#       <td id="T_03d9d_row3_col2" class="data row3 col2" >-122.716</td>
#       <td id="T_03d9d_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_03d9d_row3_col4" class="data row3 col4" >0.029743</td>
#     </tr>
#     <tr>
#       <th id="T_03d9d_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_03d9d_row4_col0" class="data row4 col0" >486_742_0</td>
#       <td id="T_03d9d_row4_col1" class="data row4 col1" >38.826</td>
#       <td id="T_03d9d_row4_col2" class="data row4 col2" >-122.762</td>
#       <td id="T_03d9d_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_03d9d_row4_col4" class="data row4 col4" >0.023748</td>
#     </tr>
#   </tbody>
# </table>
# --- Top 5 Cells: Topological Centers (Closeness) ---
# <style type="text/css">
# </style>
# <table id="T_536d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_536d8_level0_col0" class="col_heading level0 col0" >cell_id</th>
#       <th id="T_536d8_level0_col1" class="col_heading level0 col1" >lat</th>
#       <th id="T_536d8_level0_col2" class="col_heading level0 col2" >lon</th>
#       <th id="T_536d8_level0_col3" class="col_heading level0 col3" >depth_km</th>
#       <th id="T_536d8_level0_col4" class="col_heading level0 col4" >Closeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_536d8_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_536d8_row0_col0" class="data row0 col0" >487_743_0</td>
#       <td id="T_536d8_row0_col1" class="data row0 col1" >38.824</td>
#       <td id="T_536d8_row0_col2" class="data row0 col2" >-122.819</td>
#       <td id="T_536d8_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_536d8_row0_col4" class="data row0 col4" >0.483540</td>
#     </tr>
#     <tr>
#       <th id="T_536d8_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_536d8_row1_col0" class="data row1 col0" >486_743_0</td>
#       <td id="T_536d8_row1_col1" class="data row1 col1" >38.798</td>
#       <td id="T_536d8_row1_col2" class="data row1 col2" >-122.773</td>
#       <td id="T_536d8_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_536d8_row1_col4" class="data row1 col4" >0.475116</td>
#     </tr>
#     <tr>
#       <th id="T_536d8_level0_row2" class="row_heading level0 row2" >54</th>
#       <td id="T_536d8_row2_col0" class="data row2 col0" >485_743_0</td>
#       <td id="T_536d8_row2_col1" class="data row2 col1" >38.759</td>
#       <td id="T_536d8_row2_col2" class="data row2 col2" >-122.716</td>
#       <td id="T_536d8_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_536d8_row2_col4" class="data row2 col4" >0.422420</td>
#     </tr>
#     <tr>
#       <th id="T_536d8_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_536d8_row3_col0" class="data row3 col0" >541_661_0</td>
#       <td id="T_536d8_row3_col1" class="data row3 col1" >46.197</td>
#       <td id="T_536d8_row3_col2" class="data row3 col2" >-122.190</td>
#       <td id="T_536d8_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_536d8_row3_col4" class="data row3 col4" >0.422342</td>
#     </tr>
#     <tr>
#       <th id="T_536d8_level0_row4" class="row_heading level0 row4" >300</th>
#       <td id="T_536d8_row4_col0" class="data row4 col0" >486_742_0</td>
#       <td id="T_536d8_row4_col1" class="data row4 col1" >38.826</td>
#       <td id="T_536d8_row4_col2" class="data row4 col2" >-122.762</td>
#       <td id="T_536d8_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_536d8_row4_col4" class="data row4 col4" >0.416289</td>
#     </tr>
#   </tbody>
# </table>
# --- Top 5 Cells: Stress Sinks (PageRank) ---
# <style type="text/css">
# </style>
# <table id="T_fe660">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe660_level0_col0" class="col_heading level0 col0" >cell_id</th>
#       <th id="T_fe660_level0_col1" class="col_heading level0 col1" >lat</th>
#       <th id="T_fe660_level0_col2" class="col_heading level0 col2" >lon</th>
#       <th id="T_fe660_level0_col3" class="col_heading level0 col3" >depth_km</th>
#       <th id="T_fe660_level0_col4" class="col_heading level0 col4" >PageRank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe660_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_fe660_row0_col0" class="data row0 col0" >487_743_0</td>
#       <td id="T_fe660_row0_col1" class="data row0 col1" >38.824</td>
#       <td id="T_fe660_row0_col2" class="data row0 col2" >-122.819</td>
#       <td id="T_fe660_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_fe660_row0_col4" class="data row0 col4" >0.022961</td>
#     </tr>
#     <tr>
#       <th id="T_fe660_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_fe660_row1_col0" class="data row1 col0" >486_743_0</td>
#       <td id="T_fe660_row1_col1" class="data row1 col1" >38.798</td>
#       <td id="T_fe660_row1_col2" class="data row1 col2" >-122.773</td>
#       <td id="T_fe660_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_fe660_row1_col4" class="data row1 col4" >0.018984</td>
#     </tr>
#     <tr>
#       <th id="T_fe660_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_fe660_row2_col0" class="data row2 col0" >541_661_0</td>
#       <td id="T_fe660_row2_col1" class="data row2 col1" >46.197</td>
#       <td id="T_fe660_row2_col2" class="data row2 col2" >-122.190</td>
#       <td id="T_fe660_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_fe660_row2_col4" class="data row2 col4" >0.012535</td>
#     </tr>
#     <tr>
#       <th id="T_fe660_level0_row3" class="row_heading level0 row3" >54</th>
#       <td id="T_fe660_row3_col0" class="data row3 col0" >485_743_0</td>
#       <td id="T_fe660_row3_col1" class="data row3 col1" >38.759</td>
#       <td id="T_fe660_row3_col2" class="data row3 col2" >-122.716</td>
#       <td id="T_fe660_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_fe660_row3_col4" class="data row3 col4" >0.004480</td>
#     </tr>
#     <tr>
#       <th id="T_fe660_level0_row4" class="row_heading level0 row4" >7116</th>
#       <td id="T_fe660_row4_col0" class="data row4 col0" >438_717_1</td>
#       <td id="T_fe660_row4_col1" class="data row4 col1" >38.171</td>
#       <td id="T_fe660_row4_col2" class="data row4 col2" >-117.858</td>
#       <td id="T_fe660_row4_col3" class="data row4 col3" >10.0</td>
#       <td id="T_fe660_row4_col4" class="data row4 col4" >0.004360</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Community Detection algorithm

# %% [markdown]
# ### Louvain Algorithm on Communities with > 50 cells

# %%
import networkx as nx
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import geopandas as gpd

print("  COMMUNITY DETECTION (LOUVAIN METHOD)   ")

# Louvain works best on undirected graphs so we get the giant component.
G_undirected = G_giant.to_undirected()

# Remove self-loops 
G_undirected.remove_edges_from(nx.selfloop_edges(G_undirected))

print("Running Louvain algorithm...")
communities = nx.community.louvain_communities(G_undirected, seed=42)

print(f"Algorithm discovered {len(communities)} distinct seismic communities.\n")

# community IDs to the nodes
community_mapping = {}
for comm_id, node_set in enumerate(communities):
    for node in node_set:
        community_mapping[node] = comm_id

# data for visualization
comm_data = []
for node in G_undirected.nodes():
    if 'lat' in G_undirected.nodes[node] and 'lon' in G_undirected.nodes[node]:
        comm_data.append({
            'cell_id': node,
            'community': str(community_mapping[node]),
            'lat': G_undirected.nodes[node]['lat'],
            'lon': G_undirected.nodes[node]['lon'],
            'degree': G_undirected.degree(node)
        })

df_comm = pd.DataFrame(comm_data)

# Filter tiny communities to make the map readable
# communities with > 50 cells
comm_counts = df_comm['community'].value_counts()
large_communities = comm_counts[comm_counts >= 50].index
df_comm_filtered = df_comm[df_comm['community'].isin(large_communities)].copy()

print(f"Mapping the {len(large_communities)} largest structural fault systems...")

# get USA boundaries for the surface map
url = "https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip"
world = gpd.read_file(url)
usa_geom = world[world['ADMIN'] == "United States of America"].geometry.iloc[0]
geometries = [usa_geom] if usa_geom.geom_type == 'Polygon' else usa_geom.geoms

lons_map, lats_map = [], []
for polygon in geometries:
    x, y = polygon.exterior.coords.xy
    lons_map.extend(x)
    lats_map.extend(y)
    lons_map.append(None)
    lats_map.append(None)

# Plot the Communities
fig_comm = px.scatter_geo(
    df_comm_filtered, 
    lat="lat", 
    lon="lon", 
    color="community", 
    size="degree",     # hubs
    color_discrete_sequence=px.colors.qualitative.Bold,
    hover_name="community",
    hover_data={"lat": ":.3f", "lon": ":.3f", "degree": True},
    title="Earthquake communities (Louvain Method)",
    scope="north america" 
)

fig_comm.update_traces(marker=dict(size=3, opacity=0.8, line=dict(width=0)))
fig_comm.update_geos(
    showsubunits=True, 
    subunitcolor="LightGray",
    showcountries=True,
    countrycolor="Black",
    lataxis_range=[24.6, 50],
    lonaxis_range=[-125, -65]
)

fig_comm.update_layout(
    margin={"r": 0, "t": 40, "l": 0, "b": 0}, 
    showlegend=True, 
    geo=dict(bgcolor='rgba(0,0,0,0)') 
)

fig_comm.show()
# Out:
#   COMMUNITY DETECTION (LOUVAIN METHOD)
# Running Louvain algorithm...
# Algorithm discovered 20 distinct seismic communities.
#
# Mapping the 16 largest structural fault systems...
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_56.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Louvain Algorithm on TOP 10 Communities with > 50 cells

# %%
import networkx as nx
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import geopandas as gpd

print("  COMMUNITY DETECTION (LOUVAIN METHOD)   ")

G_undirected = G_giant.to_undirected()

# Remove self-loops
G_undirected.remove_edges_from(nx.selfloop_edges(G_undirected))

print("Running Louvain algorithm...")
communities = nx.community.louvain_communities(G_undirected, seed=42)

print(f"Algorithm discovered {len(communities)} distinct seismic communities.\n")

# community IDs to the nodes
community_mapping = {}
for comm_id, node_set in enumerate(communities):
    for node in node_set:
        community_mapping[node] = comm_id

# Extract data visualization
comm_data = []
for node in G_undirected.nodes():
    if 'lat' in G_undirected.nodes[node] and 'lon' in G_undirected.nodes[node]:
        comm_data.append({
            'cell_id': node,
            'community': str(community_mapping[node]),
            'lat': G_undirected.nodes[node]['lat'],
            'lon': G_undirected.nodes[node]['lon'],
            'degree': G_undirected.degree(node)
        })

df_comm = pd.DataFrame(comm_data)

# Filter tiny communities to make the map readable
# communities with > 50 cells
comm_counts = df_comm['community'].value_counts()
large_communities = comm_counts[comm_counts >= 50].index
df_comm_filtered = df_comm[df_comm['community'].isin(large_communities)].copy()

print(f"Mapping the {len(large_communities)} largest structural fault systems...")

# get USA boundaries for the surface map
url = "https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip"
world = gpd.read_file(url)
usa_geom = world[world['ADMIN'] == "United States of America"].geometry.iloc[0]
geometries = [usa_geom] if usa_geom.geom_type == 'Polygon' else usa_geom.geoms

lons_map, lats_map = [], []
for polygon in geometries:
    x, y = polygon.exterior.coords.xy
    lons_map.extend(x)
    lats_map.extend(y)
    lons_map.append(None)
    lats_map.append(None)
    
# FILTER top 10 communities
top_10_communities = df_comm['community'].value_counts().nlargest(10).index
df_comm_filtered = df_comm[df_comm['community'].isin(top_10_communities)].copy()

print(f"Mapping ONLY the top 10 macro-fault systems...")

fig_comm = px.scatter_geo(
    df_comm_filtered, 
    lat="lat", 
    lon="lon", 
    color="community", 
    color_discrete_sequence=px.colors.qualitative.Bold, 
    hover_name="community",
    hover_data={"lat": ":.3f", "lon": ":.3f", "degree": True},
    title="Top 10 Macro-Seismic Communities in the USA",
    scope="north america"
)

fig_comm.update_traces(marker=dict(size=3, opacity=0.8, line=dict(width=0)))
fig_comm.update_geos(
    showsubunits=True, 
    subunitcolor="LightGray",
    showcountries=True,
    countrycolor="Black",
    lataxis_range=[24.6, 50],
    lonaxis_range=[-125, -65]
)

fig_comm.update_layout(
    margin={"r": 0, "t": 40, "l": 0, "b": 0}, 
    showlegend=True, 
    geo=dict(bgcolor='rgba(0,0,0,0)') 
)

fig_comm.show()
# Out:
#   COMMUNITY DETECTION (LOUVAIN METHOD)
# Running Louvain algorithm...
# Algorithm discovered 20 distinct seismic communities.
#
# Mapping the 16 largest structural fault systems...
# Mapping ONLY the top 10 macro-fault systems...
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_55.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## SAVE Centrality Results
# - CellID
# - Degree
# - Betweenness
# - Closeness
# - PageRank

# %%
# Merge the centrality data with the community data and cell_id
df_final_results = pd.merge(df_centrality, df_comm[['cell_id', 'community']], on='cell_id', how='left')

# Save to CSV with metrics
df_final_results.to_csv("results/us_eq_network_metrics.csv", index=False)
print("data exported to 'us_eq_network_metrics.csv'!")
# Out:
# data exported to 'us_eq_network_metrics.csv'!
